# %%
import pandas as pd

# %%
def read_owu(file, root_path = 'dataset/datahow_2020/insilico_data'):
	data = pd.read_csv(f'{root_path}/{file}.csv')
	owu_df = data.copy()
	owu_df.set_index(['run', 'time'], inplace=True)
	return owu_df

# %%
root_path = 'dataset/datahow_2020/insilico_data/interpolation'
owu = read_owu('owu', root_path=root_path)
owu_test = read_owu('owu_test', root_path=root_path)

# %%
owu_test
# Out:
#           timesteps     X:VCD       X:Glc      X:Gln      X:NH4       X:Lac  \
# run time
# 20  0             0  0.200000   20.000000   3.000000   0.100000    0.100000
#     1            24  0.465052   12.344838   1.930211   0.995202    1.557998
#     2            48  0.823930   14.878785   1.247687   1.008069    6.053220
#     3            72  1.615609    9.630062   0.400731   1.198852   14.785587
#     4            96  2.375978    7.224935   4.691588   3.049815   18.807655
# ...             ...       ...         ...        ...        ...         ...
# 92  10          240  2.331238  186.882758  20.355289  23.613723   99.552011
#     11          264  1.951967  227.126447  21.106760  23.439616  109.905780
#     12          288  1.676322  196.634521  18.388996  30.926542   82.337328
#     13          312  1.335594  302.457306  31.741710  40.371787  110.847810
#     14          336  1.206386  251.664580  24.637519  44.420126  108.482225
#
#              X:Titer  W:pH  W:Temp  F:Feed_Glc  F:Feed_Gln
# run time
# 20  0       0.000000   6.9    36.0         0.0         0.0
#     1       8.444000   6.9    36.0         0.0         0.0
#     2      21.431336   6.9    36.0         0.0         0.0
#     3      30.070268   6.9    36.0         5.0         6.0
#     4      86.763520   6.9    36.0         5.0         6.0
# ...              ...   ...     ...         ...         ...
# 92  10    700.302829   7.1    36.0        30.0         6.0
#     11    700.650801   7.1    36.0        30.0         6.0
#     12    778.432280   7.1    36.0        30.0         6.0
#     13    710.228495   7.1    36.0         0.0         0.0
#     14    846.086351   7.0    37.0         0.0         0.0
#
# [330 rows x 11 columns]
